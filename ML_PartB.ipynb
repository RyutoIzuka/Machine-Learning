# %% [markdown]
# <a href="https://colab.research.google.com/github/RyutoIzuka/Machine-Learning/blob/main/ML_PartB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-d188be72-caa8-4db3-b3a0-9b34ca14136c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d188be72-caa8-4db3-b3a0-9b34ca14136c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CRM.csv to CRM (1).csv

# %%
dataset = pd.read_csv("CRM.csv")
dataset.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-01-04  222.639999  223.750000  215.720001  220.309998  220.309998
# 1  2021-01-05  219.490005  223.000000  217.990005  221.520004  221.520004
# 2  2021-01-06  218.000000  220.460007  215.779999  216.149994  216.149994
# 3  2021-01-07  217.029999  220.660004  216.500000  217.979996  217.979996
# 4  2021-01-08  220.000000  222.320007  219.220001  222.039993  222.039993
#
#      Volume
# 0  10319900
# 1   8657200
# 2   9789800
# 3   8443100
# 4   7301700

# %%
dataset.isnull
# Out:
# <bound method DataFrame.isnull of            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-01-04  222.639999  223.750000  215.720001  220.309998  220.309998
# 1    2021-01-05  219.490005  223.000000  217.990005  221.520004  221.520004
# 2    2021-01-06  218.000000  220.460007  215.779999  216.149994  216.149994
# 3    2021-01-07  217.029999  220.660004  216.500000  217.979996  217.979996
# 4    2021-01-08  220.000000  222.320007  219.220001  222.039993  222.039993
# ..          ...         ...         ...         ...         ...         ...
# 246  2021-12-23  251.229996  254.309998  249.339996  253.139999  253.139999
# 247  2021-12-27  253.389999  258.429993  253.240005  258.299988  258.299988
# 248  2021-12-28  259.730011  260.779999  254.940002  255.449997  255.449997
# 249  2021-12-29  256.000000  256.429993  253.119995  254.539993  254.539993
# 250  2021-12-30  255.300003  257.899994  254.460007  255.330002  255.330002
#
#        Volume
# ...

# %%
numerical_variable = dataset.columns[dataset.dtypes != 'object']
categorical_variable = dataset.columns[dataset.dtypes == 'object']
dataset[categorical_variable]
# Out:
#            Date
# 0    2021-01-04
# 1    2021-01-05
# 2    2021-01-06
# 3    2021-01-07
# 4    2021-01-08
# ..          ...
# 246  2021-12-23
# 247  2021-12-27
# 248  2021-12-28
# 249  2021-12-29
# 250  2021-12-30
#
# [251 rows x 1 columns]

# %%
dataset[numerical_variable].isnull()
dataset[categorical_variable].isnull()
#Dataset is clean
# Out:
#       Date
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 246  False
# 247  False
# 248  False
# 249  False
# 250  False
#
# [251 rows x 1 columns]

# %%
dataset.replace(0, 'Low')
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-01-04  222.639999  223.750000  215.720001  220.309998  220.309998
# 1    2021-01-05  219.490005  223.000000  217.990005  221.520004  221.520004
# 2    2021-01-06  218.000000  220.460007  215.779999  216.149994  216.149994
# 3    2021-01-07  217.029999  220.660004  216.500000  217.979996  217.979996
# 4    2021-01-08  220.000000  222.320007  219.220001  222.039993  222.039993
# ..          ...         ...         ...         ...         ...         ...
# 246  2021-12-23  251.229996  254.309998  249.339996  253.139999  253.139999
# 247  2021-12-27  253.389999  258.429993  253.240005  258.299988  258.299988
# 248  2021-12-28  259.730011  260.779999  254.940002  255.449997  255.449997
# 249  2021-12-29  256.000000  256.429993  253.119995  254.539993  254.539993
# 250  2021-12-30  255.300003  257.899994  254.460007  255.330002  255.330002
#
#        Volume
# 0    10319900
# 1     8657200
# ...

# %%
dataset.isnull().mean() * 100
#Missing percent is 0%
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %%
date = ['Date']
low = ['Low']

# %%
plt.plot()
plt.title('Date VS Low')
plt.xlabel('Date')
plt.ylabel('Low')
plt.show()

# %%
x_variable = ['Date']
y_variable = ['Low']
len(x_variable)
x= dataset[x_variable].values.reshape(-1,1) #1st value is -1, next value is the length of x_variable
y= dataset[y_variable].values.reshape(-1,1)
print(x.shape)
print(y.shape)
# Out:
# (251, 1)
# (251, 1)

# %%
Lin_reg = LinearRegression()
